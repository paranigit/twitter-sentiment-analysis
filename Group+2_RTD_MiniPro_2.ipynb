# %% [markdown]
# ### PART 2 - Process the Twitter Data in Real time using Spark Streaming & Kafka Consumer

# %%
import sys # used to exit
import json, re
import datetime, time

from __future__ import print_function

# %%
# Spark Streaming Libs
from pyspark import SparkContext
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils

# %%
# Create a Spark Context
sc = SparkContext(appName="Group2_RTD_SparkStreaming")

# %%
# Create a Streaming Context
sc.setLogLevel("WARN")
ssc = StreamingContext(sc,10)

# %% [markdown]
# #### Setup Kafka Stream (Consumer) to get the tweets from the topic
# Note: Here we use the broker server from Cloud Lab.

# %%
# Create a KafkaStream
kafkaStream = KafkaUtils.createStream(ssc, 'ip-20-0-32-4.ap-south-1.compute.internal:2181', 'spark-streaming', {'rtd2analysis':1})

# %%
ssc.checkpoint("checkpoint")

# %% [markdown]
# #### Lets create a function to filter stop words & emojis from the twitter text

# %%
import nltk
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

def cleanTweet(tweet):
    less_stopwords = ' '.join([word for word in tweet.split() if word not in stop_words])
    return ' '.join(re.sub("(@[0-9*#+/]+)|([^0-9A-Za-z@:/._ \t])", " ", less_stopwords).split())

# %%
# Func to add all values
def updateFunction(new_values, last_sum):
    return sum(new_values) + (last_sum or 0)

# %%
# parse the tweet data
parsed = kafkaStream.map(lambda v: json.loads(v[1].encode("ascii", "ignore")))

# %% [markdown]
# ### 1. Find Influential people in twitter:
# Find top 10 Influential personalities from the twitter across the globe. (In an interval of 10 seconds).

# %%
# Get the user & their followers count
follower_counts = parsed.map(lambda tweet: (tweet['user']['screen_name'],tweet['user']['followers_count'])).reduceByKey(lambda x,y: y)

# Print Top 10 users with most followers in last 10 secs
sorted_FollowerCounts = follower_counts.transform(lambda foo:foo.sortBy(lambda x:x[1],ascending=False))
sorted_FollowerCounts.pprint(num=10)

# %% [markdown]
# ### 2. Get trending Topics in twitter right now:
# Find the word from the tweet which is occurring most of the times in the whole tweets corpus.
# Top 10 trending topic (In an interval of 10 seconds).

# %% [markdown]
# Note: To find the word from the tweet which is occurring most of the times in the whole tweets corpus, we have to cumulate the counts all time.

# %%
# Get text part if the tweet & clean the same
texts = parsed.map(lambda tweet: cleanTweet(tweet['text']))

# Split the text into words
# For simplicity lets select only words with length less or equal to 20 and greater than 5.
text_counts = texts.flatMap(lambda text: text.split(" ")).map(lambda word:(word,len(word))).filter(lambda t: t[1] <= 20 and t[1] > 5).reduceByKey(lambda x,y: x + y)

# Calculate cumulative counts for words
runningWordCounts = text_counts.updateStateByKey(updateFunction)

# Sort & Order
sorted_WordCounts = runningWordCounts.transform(lambda foo:foo.sortBy(lambda x:x[0]).sortBy(lambda x:x[1],ascending=False))

# print the top 10 Count
sorted_WordCounts.pprint(num=10)

# %%
try:
    ssc.start()
    ssc.awaitTerminationOrTimeout(1000)
    ssc.stop(stopGraceFully=True,stopSparkContext=True)
    
except KeyboardInterrupt:
    ssc.stop(stopGraceFully=True,stopSparkContext=True)
# Out:
# -------------------------------------------
# Time: 2018-08-26 02:47:30
# -------------------------------------------
# (u'radioyskl', 81794)
# (u'fhay_cotton_h', 24502)
# (u'varelacl', 14097)
# (u'tingilye', 13319)
# (u'ThinkSmart2011', 10804)
# (u'DeppCulture', 9446)
# (u'fwckook', 7226)
# (u'iAmJCotti', 6055)
# (u'millarly', 5986)
# (u'Havanaxeri', 5712)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:47:30
# -------------------------------------------
# (u'FFArtistShawn', 65)
# (u'PAPASA', 48)
# (u'SelenaGomez', 44)
# (u'really', 36)
# (u'@BTS_twt', 32)
# (u'@YouTube', 32)
# (u'@JudicialWatch:', 30)
# (u'@ProjetoCabraRE', 30)
# (u'McCain', 30)
# (u'LarissaManoela', 28)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:47:40
# -------------------------------------------
# (u'Moginiki', 45344)
# (u'Tt3b1', 35084)
# (u'sueatia', 34290)
# (u'numsaeng13', 30710)
# (u'Euraridade', 26251)
# (u'tssuec', 24696)
# (u'peeprlxrd', 17866)
# (u'unseen1_unseen', 13264)
# (u'morfi', 12818)
# (u'worthybieber', 12452)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:47:40
# -------------------------------------------
# (u'FFArtistShawn', 91)
# (u'McCain', 78)
# (u'@BTS_twt', 72)
# (u'SelenaGomez', 66)
# (u'@YouTube', 48)
# (u'PAPASA', 48)
# (u'following', 45)
# (u'really', 42)
# (u'AnittaGata', 40)
# (u'180825', 36)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:47:50
# -------------------------------------------
# (u'Corp125Vet', 49251)
# (u'Smusouzan_nexon', 47108)
# (u'Sheffieldis', 28322)
# (u'BellaMoreira8', 25416)
# (u'Osh0099', 19102)
# (u'KarenPiper7', 18825)
# (u'OmarBryant_', 18150)
# (u'FanSince09', 15619)
# (u'Karla79609348', 12254)
# (u'JoRichardsKent', 10774)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:47:50
# -------------------------------------------
# (u'FFArtistShawn', 130)
# (u'@BTS_twt', 128)
# (u'McCain', 114)
# (u'SelenaGomez', 66)
# (u'iHeartRadioMMVAs', 64)
# (u'@YouTube', 56)
# (u'friends', 56)
# (u'following', 54)
# (u'country', 49)
# (u'@MostRequestLive', 48)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:48:00
# -------------------------------------------
# (u'GainVVIP', 110674)
# (u'fakharqasmi', 42935)
# (u'ExploreEdmonton', 39421)
# (u'ttdogiu', 25311)
# (u'MinnieBesT', 18485)
# (u'ranxiangmm', 14921)
# (u'chghimire', 9869)
# (u'cheerio15', 9507)
# (u'BHULLAR_22_', 8180)
# (u'SakurabaKaname', 6968)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:48:00
# -------------------------------------------
# (u'@BTS_twt', 168)
# (u'FFArtistShawn', 156)
# (u'McCain', 144)
# (u'iHeartRadioMMVAs', 112)
# (u'180825', 72)
# (u'@YouTube', 72)
# (u'@VOTESUPDATESS', 70)
# (u'FFArtistCamila', 70)
# (u'SelenaGomez', 66)
# (u'people', 66)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:48:10
# -------------------------------------------
# (u'Love_McD', 173066)
# (u'Mel365dotCom', 108846)
# (u'GuardiaDigital', 80669)
# (u'AnthemRespect', 67545)
# (u'Bathaksaudi', 52463)
# (u'WowToday_', 26493)
# (u'Juaniisimo', 26467)
# (u'Diana_gamal1', 26236)
# (u'RonCunningham', 17415)
# (u'beretta_gio', 11386)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:48:10
# -------------------------------------------
# (u'@BTS_twt', 224)
# (u'FFArtistShawn', 208)
# (u'McCain', 168)
# (u'iHeartRadioMMVAs', 144)
# (u'180825', 114)
# (u'@VOTESUPDATESS', 98)
# (u'FFArtistCamila', 98)
# (u'people', 96)
# (u'automatically', 78)
# (u'BTSLoveYourselfTour', 76)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:48:20
# -------------------------------------------
# (u'Love_McD', 173065)
# (u'tituv2000', 75408)
# (u'DavidWallaceBRA', 43080)
# (u'otokita', 37258)
# (u'iMac_too', 25512)
# (u'dlongenecker1', 19947)
# (u'ambinc1', 15491)
# (u'BG_COKLAT69', 14727)
# (u'danlan_jp', 11978)
# (u'Priyank94585845', 10576)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:48:20
# -------------------------------------------
# (u'@BTS_twt', 272)
# (u'FFArtistShawn', 247)
# (u'McCain', 222)
# (u'iHeartRadioMMVAs', 192)
# (u'@VOTESUPDATESS', 126)
# (u'FFArtistCamila', 126)
# (u'180825', 120)
# (u'@ProjetoCabraRE', 120)
# (u'people', 114)
# (u'SelenaGomez', 99)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:48:30
# -------------------------------------------
# (u'kw_s37', 160485)
# (u'darhar981', 45209)
# (u'desimasi2', 41673)
# (u'ThomasVLinge', 41359)
# (u'Pizzazz_Books', 27282)
# (u'barbiedsite', 19916)
# (u'3elmeeat', 19398)
# (u'MinnieBesT', 18485)
# (u'veterans_i', 17980)
# (u'HoraDaVenenosa', 17482)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:48:30
# -------------------------------------------
# (u'@BTS_twt', 304)
# (u'McCain', 276)
# (u'FFArtistShawn', 273)
# (u'iHeartRadioMMVAs', 224)
# (u'180825', 144)
# (u'FFArtistCamila', 140)
# (u'people', 138)
# (u'@YouTube', 128)
# (u'@realDonaldTrump', 128)
# (u'@VOTESUPDATESS', 126)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:48:40
# -------------------------------------------
# (u'hauaoui', 120299)
# (u'InSpiteOfTrump', 40104)
# (u'rorippi', 26894)
# (u'ClllD__', 21711)
# (u'jkaruaru2014', 17977)
# (u'StaceyLovesWeed', 15319)
# (u'kccperfcts', 14123)
# (u'brownroundboi', 12043)
# (u'noorsyria71', 11993)
# (u'DiBibir', 10454)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:48:40
# -------------------------------------------
# (u'@BTS_twt', 344)
# (u'McCain', 312)
# (u'FFArtistShawn', 299)
# (u'iHeartRadioMMVAs', 256)
# (u'FFArtistCamila', 182)
# (u'180825', 174)
# (u'@VOTESUPDATESS', 168)
# (u'people', 162)
# (u'BTSLoveYourselfTour', 152)
# (u'@ProjetoCabraRE', 150)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:48:50
# -------------------------------------------
# (u'CanalRapRJ', 27321)
# (u'OldSchRides', 18477)
# (u'lovatohnizer', 15864)
# (u'Kn_____22', 11107)
# (u'I_Bl33d_Purple', 9677)
# (u'hipstrrz', 9562)
# (u'vvmbart', 8953)
# (u'gukkyj', 8808)
# (u'zzz5533', 7649)
# (u'bangtangelz', 5772)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:48:50
# -------------------------------------------
# (u'@BTS_twt', 400)
# (u'McCain', 378)
# (u'FFArtistShawn', 338)
# (u'iHeartRadioMMVAs', 256)
# (u'@realDonaldTrump', 208)
# (u'180825', 198)
# (u'FFArtistCamila', 182)
# (u'@ProjetoCabraRE', 180)
# (u'people', 180)
# (u'@VOTESUPDATESS', 168)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:49:00
# -------------------------------------------
# (u'IAmSophiaNelson', 46323)
# (u'bielcarva11', 36077)
# (u'RNcat50', 27788)
# (u'top__today', 26386)
# (u'music_uw25', 21425)
# (u'emooly2', 18589)
# (u'cheeenle', 13712)
# (u'AleLaKuka', 12633)
# (u'leah_macrae', 12405)
# (u'AleksSalazar', 12226)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:49:00
# -------------------------------------------
# (u'@BTS_twt', 432)
# (u'McCain', 414)
# (u'FFArtistShawn', 364)
# (u'iHeartRadioMMVAs', 272)
# (u'180825', 246)
# (u'@ProjetoCabraRE', 210)
# (u'people', 210)
# (u'@realDonaldTrump', 208)
# (u'FFArtistCamila', 182)
# (u'BTSLoveYourselfTour', 171)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:49:10
# -------------------------------------------
# (u'AmazonHelp', 179242)
# (u'OhYesPups', 135584)
# (u'Heryrevi', 81654)
# (u'wessexual', 66318)
# (u'minminTV', 61914)
# (u'0o2030', 37418)
# (u'hepbvrnn', 32582)
# (u'kk_7899', 30986)
# (u'Osam_U', 30497)
# (u'MENS_EX', 26627)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:49:10
# -------------------------------------------
# (u'@BTS_twt', 488)
# (u'McCain', 450)
# (u'FFArtistShawn', 390)
# (u'iHeartRadioMMVAs', 288)
# (u'180825', 270)
# (u'people', 234)
# (u'@ProjetoCabraRE', 225)
# (u'@realDonaldTrump', 224)
# (u'BTSLoveYourselfTour', 190)
# (u'FFArtistCamila', 182)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:49:20
# -------------------------------------------
# (u'CPTM_oficial', 691879)
# (u'anisama', 140649)
# (u'ProfElvanAktas', 76309)
# (u'ffoloR_bocaJ', 28303)
# (u'igorrealequatro', 19814)
# (u'rn_gal', 11975)
# (u'IamSkDaiya', 11326)
# (u'hatem_720', 9211)
# (u'KimSnodgrass', 8692)
# (u'RinaJS', 8388)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:49:20
# -------------------------------------------
# (u'@BTS_twt', 536)
# (u'McCain', 504)
# (u'FFArtistShawn', 416)
# (u'iHeartRadioMMVAs', 288)
# (u'180825', 282)
# (u'people', 282)
# (u'@realDonaldTrump', 240)
# (u'BTSLoveYourselfTour', 228)
# (u'@ProjetoCabraRE', 225)
# (u'FFArtistCamila', 196)
# ...
# -------------------------------------------
# Time: 2018-08-26 02:49:30
# -------------------------------------------
# (u's_5022s', 15991)
# (u'npnp333', 13604)
# (u'langernutrition', 12404)
# (u'JONATASFFC_00', 12239)
# (u'danlan_jp', 11978)
# (u'taki7', 11940)
# (u'SEXYSLARRY', 8757)
# (u'Jeje_Jones', 8679)
# (u'mcutholland', 6815)
# (u'LibertyLynx', 6810)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:49:30
# -------------------------------------------
# (u'McCain', 558)
# (u'@BTS_twt', 552)
# (u'FFArtistShawn', 455)
# (u'people', 306)
# (u'iHeartRadioMMVAs', 304)
# (u'180825', 288)
# (u'@realDonaldTrump', 256)
# (u'BTSLoveYourselfTour', 247)
# (u'@ProjetoCabraRE', 240)
# (u'YTUnfreezeIDOL', 238)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:49:40
# -------------------------------------------
# (u'monst_campaign', 565462)
# (u'sexandtw_', 57426)
# (u's_5022s', 15991)
# (u'VoteHarryLane', 15170)
# (u'_little_old_me', 15060)
# (u'rxbelzjm', 11103)
# (u'JSandlinWriter', 9328)
# (u'OT7uwu', 8667)
# (u'briaxsym', 6305)
# (u'BigBadBosnia', 6177)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:49:40
# -------------------------------------------
# (u'McCain', 612)
# (u'@BTS_twt', 584)
# (u'FFArtistShawn', 481)
# (u'people', 324)
# (u'@realDonaldTrump', 320)
# (u'iHeartRadioMMVAs', 320)
# (u'180825', 306)
# (u'@ProjetoCabraRE', 255)
# (u'BTSLoveYourselfTour', 247)
# (u'YTUnfreezeIDOL', 238)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:49:50
# -------------------------------------------
# (u'KHNews', 164421)
# (u'sugafull27', 155065)
# (u'mh1396', 75187)
# (u'ro7alro777', 26360)
# (u'pceyeolr', 18700)
# (u'taehyugc', 15466)
# (u'_resentidaa', 13330)
# (u'WarriorofGod97', 11713)
# (u'RidzwanMahazan', 11156)
# (u'MoniseLSeward', 8835)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:49:50
# -------------------------------------------
# (u'McCain', 654)
# (u'@BTS_twt', 608)
# (u'FFArtistShawn', 481)
# (u'people', 342)
# (u'@realDonaldTrump', 336)
# (u'180825', 324)
# (u'iHeartRadioMMVAs', 320)
# (u'@ProjetoCabraRE', 255)
# (u'BTSLoveYourselfTour', 247)
# (u'Senator', 238)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:50:00
# -------------------------------------------
# (u'kw_s37', 160485)
# (u'vie106', 45453)
# (u'hbt_7493', 21269)
# (u'Steffs_tweets', 16172)
# (u'damonayoung', 11218)
# (u'SL_plummer', 10337)
# (u'therainbowwhale', 9426)
# (u'ljs1479', 8215)
# (u'pjmfetish', 7787)
# (u'GolazoDan', 7110)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:50:00
# -------------------------------------------
# (u'McCain', 684)
# (u'@BTS_twt', 640)
# (u'FFArtistShawn', 559)
# (u'people', 372)
# (u'@realDonaldTrump', 368)
# (u'iHeartRadioMMVAs', 352)
# (u'180825', 342)
# (u'@ProjetoCabraRE', 285)
# (u'BTSLoveYourselfTour', 285)
# (u'YTUnfreezeIDOL', 266)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:50:10
# -------------------------------------------
# (u'GolCaracol', 3568959)
# (u'trboxing', 352277)
# (u'18XTC', 126343)
# (u'henjo_official', 47428)
# (u'fmg150', 33632)
# (u'kk_7899', 30986)
# (u'FRodriguezG', 23182)
# (u'lovelivepress', 20541)
# (u'JSUGamecocks', 15577)
# (u'juajosdaluz', 15402)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:50:10
# -------------------------------------------
# (u'McCain', 750)
# (u'@BTS_twt', 712)
# (u'FFArtistShawn', 585)
# (u'people', 384)
# (u'180825', 372)
# (u'@realDonaldTrump', 368)
# (u'iHeartRadioMMVAs', 352)
# (u'@ProjetoCabraRE', 300)
# (u'BTSLoveYourselfTour', 285)
# (u'YTUnfreezeIDOL', 266)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:50:20
# -------------------------------------------
# (u'Love_McD', 173070)
# (u'Qi7__', 151674)
# (u'KNP2BP', 74258)
# (u'sexandtw_', 57426)
# (u'biore_faceca_jp', 53953)
# (u'rlthingy2', 32511)
# (u'quientvpanama', 27836)
# (u'BCortezEA', 18402)
# (u'mujercandanga', 16285)
# (u'JotaKar', 14020)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:50:20
# -------------------------------------------
# (u'McCain', 786)
# (u'@BTS_twt', 776)
# (u'FFArtistShawn', 598)
# (u'180825', 420)
# (u'people', 420)
# (u'@realDonaldTrump', 400)
# (u'iHeartRadioMMVAs', 352)
# (u'@ProjetoCabraRE', 315)
# (u'BTSLoveYourselfTour', 304)
# (u'YTUnfreezeIDOL', 294)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:50:30
# -------------------------------------------
# (u'Omarel44', 40244)
# (u'SukhpalKhaira', 31732)
# (u'indomymenfess', 28959)
# (u'turuokakamo', 26459)
# (u'Nassukun', 14286)
# (u'N5Ort', 9930)
# (u'AndradeMagaly', 9693)
# (u'LedySoa', 9203)
# (u'righthoseok', 9089)
# (u'RT4D1', 8219)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:50:30
# -------------------------------------------
# (u'McCain', 810)
# (u'@BTS_twt', 808)
# (u'FFArtistShawn', 598)
# (u'180825', 438)
# (u'people', 432)
# (u'@realDonaldTrump', 416)
# (u'iHeartRadioMMVAs', 368)
# (u'BTSLoveYourselfTour', 342)
# (u'@MostRequestLive', 320)
# (u'@ProjetoCabraRE', 315)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:50:40
# -------------------------------------------
# (u'18_sluts', 54828)
# (u'bombsfall', 54732)
# (u'MOU_st6', 30893)
# (u'PechuGordita', 23756)
# (u'hoshipika158', 22248)
# (u'BqpyT0c', 14195)
# (u'kkdddggh', 13695)
# (u'MIdifference2', 12481)
# (u'LeeBuback', 10517)
# (u'cuntaeil', 8944)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:50:40
# -------------------------------------------
# (u'@BTS_twt', 896)
# (u'McCain', 882)
# (u'FFArtistShawn', 598)
# (u'people', 468)
# (u'180825', 462)
# (u'@realDonaldTrump', 448)
# (u'iHeartRadioMMVAs', 400)
# (u'BTSLoveYourselfTour', 361)
# (u'@MostRequestLive', 336)
# (u'YTUnfreezeIDOL', 336)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:50:50
# -------------------------------------------
# (u'DolarToday', 3316993)
# (u'mankai_company', 488459)
# (u'gloomynews', 67541)
# (u'ClllD__', 21711)
# (u'gbright918', 11463)
# (u'issoqueeamorls', 11034)
# (u'CesarAGA', 11021)
# (u'pmi_diy', 10173)
# (u'IMJWALA', 9880)
# (u'YldrrY', 9136)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:50:50
# -------------------------------------------
# (u'McCain', 900)
# (u'@BTS_twt', 896)
# (u'FFArtistShawn', 611)
# (u'people', 486)
# (u'180825', 480)
# (u'@realDonaldTrump', 464)
# (u'YTUnfreezeIDOL', 462)
# (u'iHeartRadioMMVAs', 432)
# (u'BTSLoveYourselfTour', 361)
# (u'@MostRequestLive', 352)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:51:00
# -------------------------------------------
# (u'mankai_company', 488459)
# (u'gstv1lol', 122308)
# (u'kittymayo7101', 73027)
# (u'bernamaradio', 59754)
# (u'__farzanaa', 41683)
# (u'0o2030', 37418)
# (u'southstands303', 23904)
# (u'L0veBoobs', 23796)
# (u'PBMsmite', 12092)
# (u'ahmd11223344', 10705)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:51:00
# -------------------------------------------
# (u'@BTS_twt', 968)
# (u'McCain', 918)
# (u'FFArtistShawn', 611)
# (u'@realDonaldTrump', 512)
# (u'people', 510)
# (u'180825', 504)
# (u'YTUnfreezeIDOL', 490)
# (u'iHeartRadioMMVAs', 448)
# (u'BTSLoveYourselfTour', 418)
# (u'@MostRequestLive', 416)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:51:10
# -------------------------------------------
# (u'mankai_company', 488459)
# (u'BolaBanget', 39687)
# (u'skypenzomiguel', 26887)
# (u'Udaa_Johny', 17834)
# (u'VisionOfVIII', 16599)
# (u'sarahatef_', 14658)
# (u'KarolsCorner', 13859)
# (u'Twice_love5', 12991)
# (u'Blacktradelines', 11136)
# (u'yeojjaw', 10452)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:51:10
# -------------------------------------------
# (u'@BTS_twt', 1016)
# (u'McCain', 924)
# (u'FFArtistShawn', 624)
# (u'people', 522)
# (u'YTUnfreezeIDOL', 518)
# (u'180825', 516)
# (u'@realDonaldTrump', 512)
# (u'iHeartRadioMMVAs', 464)
# (u'@MostRequestLive', 432)
# (u'BTSLoveYourselfTour', 418)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:51:20
# -------------------------------------------
# (u'mankai_company', 488459)
# (u'Datos365', 262383)
# (u'YouKnowJust', 140526)
# (u'madisongesiotto', 59907)
# (u'vip2015www', 43186)
# (u'Rubicon567', 35205)
# (u'SathriYan_', 31319)
# (u'axisnet0511', 16807)
# (u'amolparashar', 15039)
# (u'PattyButts', 10337)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:51:20
# -------------------------------------------
# (u'@BTS_twt', 1080)
# (u'McCain', 960)
# (u'FFArtistShawn', 663)
# (u'YTUnfreezeIDOL', 588)
# (u'180825', 534)
# (u'people', 528)
# (u'@realDonaldTrump', 512)
# (u'iHeartRadioMMVAs', 512)
# (u'BTSLoveYourselfTour', 437)
# (u'@MostRequestLive', 432)
# ...
# -------------------------------------------
# Time: 2018-08-26 02:51:30
# -------------------------------------------
# (u'mankai_company', 488459)
# (u'jjjyyy16', 38720)
# (u'marthakorrine', 25287)
# (u'sectest9', 20101)
# (u'ahmadriyadh20', 14660)
# (u'Tr_q81', 12982)
# (u'eduard0gil', 11047)
# (u'a_pegacao', 10428)
# (u'jintaepiphany', 7114)
# (u'kana_ogawa', 6845)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:51:30
# -------------------------------------------
# (u'@BTS_twt', 1128)
# (u'McCain', 996)
# (u'FFArtistShawn', 676)
# (u'YTUnfreezeIDOL', 616)
# (u'people', 546)
# (u'@realDonaldTrump', 544)
# (u'iHeartRadioMMVAs', 544)
# (u'180825', 540)
# (u'@MostRequestLive', 480)
# (u'BTSLoveYourselfTour', 437)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:51:40
# -------------------------------------------
# (u'DiscoverSelf', 63265)
# (u'stephpadalecki', 19438)
# (u'antwanstaley', 17447)
# (u'zora107', 13194)
# (u'murilloamaral', 10490)
# (u'jimd22551', 8964)
# (u'irwinlogia', 7991)
# (u'JRFegan', 7788)
# (u'kieminjue', 7640)
# (u'chuueist', 7421)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:51:40
# -------------------------------------------
# (u'@BTS_twt', 1192)
# (u'McCain', 1020)
# (u'FFArtistShawn', 728)
# (u'YTUnfreezeIDOL', 630)
# (u'@realDonaldTrump', 560)
# (u'iHeartRadioMMVAs', 560)
# (u'people', 558)
# (u'180825', 552)
# (u'@MostRequestLive', 496)
# (u'BTSLoveYourselfTour', 494)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:51:50
# -------------------------------------------
# (u'higenjin', 172078)
# (u'bongwynnn', 28496)
# (u'3abdawya', 18450)
# (u'KarolsCorner', 13859)
# (u'wafeur', 11543)
# (u'ArteRebelde', 11509)
# (u'rxbelzjm', 11102)
# (u'breathintoronto', 9637)
# (u'marcbrooks111', 7045)
# (u'kookbxby', 6970)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:51:50
# -------------------------------------------
# (u'@BTS_twt', 1232)
# (u'McCain', 1050)
# (u'FFArtistShawn', 741)
# (u'YTUnfreezeIDOL', 644)
# (u'@realDonaldTrump', 592)
# (u'180825', 576)
# (u'iHeartRadioMMVAs', 576)
# (u'people', 570)
# (u'@MostRequestLive', 528)
# (u'BTSLoveYourselfTour', 494)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:52:00
# -------------------------------------------
# (u'PreetiSMenon', 83748)
# (u'Heizvert21', 25310)
# (u'OsakaA7med', 19786)
# (u'faateen_456', 16276)
# (u'naif0505515061', 15595)
# (u'ETuwshin', 15194)
# (u'wohl34', 13291)
# (u'TepoeN', 11311)
# (u'DclareDiane', 9543)
# (u'dreams__55', 9428)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:52:00
# -------------------------------------------
# (u'@BTS_twt', 1280)
# (u'McCain', 1074)
# (u'FFArtistShawn', 767)
# (u'YTUnfreezeIDOL', 658)
# (u'@realDonaldTrump', 624)
# (u'180825', 618)
# (u'people', 588)
# (u'iHeartRadioMMVAs', 576)
# (u'@MostRequestLive', 528)
# (u'BTSLoveYourselfTour', 513)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:52:10
# -------------------------------------------
# (u'bianet_org', 245317)
# (u'CBCEdmonton', 141085)
# (u'koki_kameda1117', 53597)
# (u'QG44HX33KY20jTM', 21466)
# (u'LyndaAtchison', 21186)
# (u'OsakaA7med', 19786)
# (u'MCJeffry', 11857)
# (u'namtalent', 10187)
# (u'SublimeSwift13', 9912)
# (u'Selena_Adera', 8211)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:52:10
# -------------------------------------------
# (u'@BTS_twt', 1320)
# (u'McCain', 1104)
# (u'FFArtistShawn', 767)
# (u'YTUnfreezeIDOL', 672)
# (u'180825', 648)
# (u'@realDonaldTrump', 624)
# (u'people', 594)
# (u'iHeartRadioMMVAs', 592)
# (u'@MostRequestLive', 544)
# (u'BTSLoveYourselfTour', 532)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:52:20
# -------------------------------------------
# (u'Sororita', 82447)
# (u'houseofaura', 47352)
# (u'zunairaali92', 45859)
# (u'0o2030', 37418)
# (u'RCdeWinter', 30110)
# (u'Cafecito_News', 26858)
# (u'ValiciaLarece_', 17764)
# (u'jr7_600', 15026)
# (u'_jayphelps', 14673)
# (u'sushmite', 10694)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:52:20
# -------------------------------------------
# (u'@BTS_twt', 1384)
# (u'McCain', 1146)
# (u'FFArtistShawn', 780)
# (u'YTUnfreezeIDOL', 672)
# (u'180825', 666)
# (u'@realDonaldTrump', 640)
# (u'iHeartRadioMMVAs', 624)
# (u'people', 606)
# (u'BTSLoveYourselfTour', 570)
# (u'@MostRequestLive', 544)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:52:30
# -------------------------------------------
# (u'untappd', 126378)
# (u'politikonline', 48106)
# (u'smalltownandrew', 43009)
# (u'SuperTrinos', 41415)
# (u'4FreeEBooks', 21184)
# (u'cyutiexx', 19047)
# (u'ALnuf333', 16899)
# (u'0OXAsVE8Q', 10468)
# (u'httpsrealitys', 9173)
# (u'selene049', 8182)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:52:30
# -------------------------------------------
# (u'@BTS_twt', 1448)
# (u'McCain', 1170)
# (u'FFArtistShawn', 793)
# (u'YTUnfreezeIDOL', 700)
# (u'180825', 690)
# (u'@realDonaldTrump', 640)
# (u'iHeartRadioMMVAs', 640)
# (u'people', 624)
# (u'BTSLoveYourselfTour', 608)
# (u'@MostRequestLive', 560)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:52:40
# -------------------------------------------
# (u'saleh_vip_1', 154741)
# (u'hauaoui', 120297)
# (u'ciudadaniactiva', 75976)
# (u'ASRGLOBALNEWS', 49987)
# (u'deejay90192', 39276)
# (u'GPronaldo13', 31944)
# (u'tripplannermama', 26841)
# (u'BasquetManresa', 25657)
# (u'HIFOON', 22050)
# (u'legendaryphrayz', 14435)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:52:40
# -------------------------------------------
# (u'@BTS_twt', 1520)
# (u'McCain', 1200)
# (u'FFArtistShawn', 793)
# (u'YTUnfreezeIDOL', 742)
# (u'180825', 738)
# (u'@realDonaldTrump', 704)
# (u'iHeartRadioMMVAs', 656)
# (u'people', 636)
# (u'BTSLoveYourselfTour', 627)
# (u'@MostRequestLive', 560)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:52:50
# -------------------------------------------
# (u'FichajeGoleador', 154830)
# (u'brucoosat', 61632)
# (u'HoneymoonGondol', 52299)
# (u'fernandabihot', 46894)
# (u'____reemoo', 44174)
# (u'Al_nassr_live', 42386)
# (u'caravanasw', 41263)
# (u'artstylws', 22088)
# (u'legal_legal69', 12189)
# (u'muna___abdu', 9125)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:52:50
# -------------------------------------------
# (u'@BTS_twt', 1560)
# (u'McCain', 1206)
# (u'FFArtistShawn', 793)
# (u'YTUnfreezeIDOL', 770)
# (u'180825', 756)
# (u'@realDonaldTrump', 720)
# (u'iHeartRadioMMVAs', 672)
# (u'BTSLoveYourselfTour', 646)
# (u'people', 642)
# (u'@MostRequestLive', 560)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:53:00
# -------------------------------------------
# (u'tabbata', 166203)
# (u'Farandula40', 120327)
# (u'KODAKUMINET', 116090)
# (u'qaroro', 58790)
# (u'KathySabine9', 29706)
# (u'AL__Faa', 25180)
# (u'3iso_', 24022)
# (u'KattLivesMatter', 21069)
# (u'PostreDulce', 17742)
# (u'5iiM7', 14378)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:53:00
# -------------------------------------------
# (u'@BTS_twt', 1600)
# (u'McCain', 1236)
# (u'FFArtistShawn', 819)
# (u'YTUnfreezeIDOL', 770)
# (u'180825', 762)
# (u'@realDonaldTrump', 720)
# (u'iHeartRadioMMVAs', 720)
# (u'BTSLoveYourselfTour', 684)
# (u'people', 672)
# (u'@MostRequestLive', 592)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:53:10
# -------------------------------------------
# (u'Love_McD', 173073)
# (u'abpanandatv', 150606)
# (u'hauaoui', 120297)
# (u'ncartmuseum', 48665)
# (u'felic_palma', 34649)
# (u'JorgeARestrepo', 19847)
# (u'linneatanner', 19568)
# (u'menicon_melsuke', 14312)
# (u'ChibaSafety', 8787)
# (u'639xiomara', 8219)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:53:10
# -------------------------------------------
# (u'@BTS_twt', 1632)
# (u'McCain', 1296)
# (u'FFArtistShawn', 832)
# (u'YTUnfreezeIDOL', 798)
# (u'180825', 780)
# (u'iHeartRadioMMVAs', 736)
# (u'@realDonaldTrump', 720)
# (u'BTSLoveYourselfTour', 684)
# (u'people', 684)
# (u'@MostRequestLive', 608)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:53:20
# -------------------------------------------
# (u'PawgWithaBlog', 575717)
# (u'CableFibertel', 212058)
# (u'alpiedeldeporte', 116711)
# (u'tsunamayoneez', 109800)
# (u'biore_faceca_jp', 53952)
# (u'aligahlib', 32040)
# (u'ClydeHaberman', 16686)
# (u'pursuitape', 11606)
# (u'Rlb2q', 9190)
# (u'LFNocha', 8714)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:53:20
# -------------------------------------------
# (u'@BTS_twt', 1648)
# (u'McCain', 1332)
# (u'FFArtistShawn', 858)
# (u'YTUnfreezeIDOL', 812)
# (u'180825', 798)
# (u'@realDonaldTrump', 752)
# (u'iHeartRadioMMVAs', 752)
# (u'people', 696)
# (u'BTSLoveYourselfTour', 684)
# (u'@MostRequestLive', 608)
# ...
# -------------------------------------------
# Time: 2018-08-26 02:53:30
# -------------------------------------------
# (u'TelkomCare', 272508)
# (u'MardaniAliSera', 106096)
# (u'maryrock180457', 56033)
# (u'sergiooliveiram', 48616)
# (u'WesterosHistory', 15579)
# (u'mdwehbie', 12937)
# (u'4annegs', 10504)
# (u'sweet2spicey12', 10072)
# (u'YUVAMARWADI', 9027)
# (u'kero__bot', 8913)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:53:30
# -------------------------------------------
# (u'@BTS_twt', 1672)
# (u'McCain', 1386)
# (u'FFArtistShawn', 884)
# (u'YTUnfreezeIDOL', 826)
# (u'180825', 816)
# (u'iHeartRadioMMVAs', 768)
# (u'@realDonaldTrump', 752)
# (u'BTSLoveYourselfTour', 741)
# (u'people', 714)
# (u'@MostRequestLive', 608)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:53:40
# -------------------------------------------
# (u'SBS8news', 441610)
# (u'Ali_Alshobaili', 176922)
# (u'MinutoAlviverde', 49607)
# (u'ARenLosDeportes', 44978)
# (u'RCdeWinter', 30110)
# (u'UnKbv2', 26746)
# (u'jclockyer', 20460)
# (u'lheal', 13777)
# (u'Little_Luxray', 13619)
# (u'PMurillopereira', 8937)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:53:40
# -------------------------------------------
# (u'@BTS_twt', 1704)
# (u'McCain', 1440)
# (u'FFArtistShawn', 897)
# (u'YTUnfreezeIDOL', 896)
# (u'180825', 822)
# (u'iHeartRadioMMVAs', 800)
# (u'@realDonaldTrump', 768)
# (u'BTSLoveYourselfTour', 760)
# (u'people', 738)
# (u'@YouTube', 632)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:53:50
# -------------------------------------------
# (u'Casper', 113725)
# (u'MichaelaOkla', 53484)
# (u'PayForJahan', 41889)
# (u'222iy', 32260)
# (u'JimOriolesTV', 15181)
# (u'mynameisntdave', 11070)
# (u'haijin_rijicho', 7462)
# (u'Tha_Bishop_', 7198)
# (u'incrrecttonyxe1', 5485)
# (u'KnudsenColleen', 4216)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:53:50
# -------------------------------------------
# (u'@BTS_twt', 1768)
# (u'McCain', 1464)
# (u'FFArtistShawn', 910)
# (u'YTUnfreezeIDOL', 910)
# (u'180825', 852)
# (u'iHeartRadioMMVAs', 816)
# (u'@realDonaldTrump', 800)
# (u'people', 768)
# (u'BTSLoveYourselfTour', 760)
# (u'@YouTube', 664)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:54:00
# -------------------------------------------
# (u'sumikaken', 135320)
# (u'gopoundsand1234', 30590)
# (u'CristinaMachuca', 17590)
# (u'seeingnjhblind', 16225)
# (u'vickibazter', 13871)
# (u'borobudur63', 13550)
# (u'hautekouture', 13307)
# (u'Saudi_Shield', 12091)
# (u'PRADO150PRADO', 11999)
# (u'sas_bot', 10248)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:54:00
# -------------------------------------------
# (u'@BTS_twt', 1800)
# (u'McCain', 1506)
# (u'FFArtistShawn', 949)
# (u'YTUnfreezeIDOL', 924)
# (u'180825', 870)
# (u'iHeartRadioMMVAs', 832)
# (u'@realDonaldTrump', 816)
# (u'people', 786)
# (u'BTSLoveYourselfTour', 779)
# (u'@YouTube', 696)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:54:10
# -------------------------------------------
# (u'Cardinals', 1180882)
# (u'7lw__', 1150042)
# (u'Love_McD', 173073)
# (u'MomsWhoSave', 123176)
# (u'ArtistRack_', 58608)
# (u'Zoz_5050', 39273)
# (u'lilidiaz8', 33195)
# (u'arrobazabdiel', 31828)
# (u'kk_7899', 30984)
# (u'BNev4666', 21019)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:54:10
# -------------------------------------------
# (u'@BTS_twt', 1832)
# (u'McCain', 1530)
# (u'FFArtistShawn', 1027)
# (u'YTUnfreezeIDOL', 938)
# (u'180825', 900)
# (u'iHeartRadioMMVAs', 848)
# (u'@realDonaldTrump', 832)
# (u'people', 810)
# (u'BTSLoveYourselfTour', 779)
# (u'@YouTube', 704)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:54:20
# -------------------------------------------
# (u'inunekome', 73380)
# (u'EleenaFisher', 54639)
# (u'TeamDanaRico', 41485)
# (u'Q10AK', 23676)
# (u'saad27257', 21660)
# (u'bero_5578', 20415)
# (u'jul2iet', 13018)
# (u'arsadpp4698095', 11259)
# (u'louisfeel', 9208)
# (u'SapnaMalik_', 8911)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:54:20
# -------------------------------------------
# (u'@BTS_twt', 1856)
# (u'McCain', 1572)
# (u'FFArtistShawn', 1040)
# (u'YTUnfreezeIDOL', 938)
# (u'180825', 930)
# (u'@realDonaldTrump', 864)
# (u'iHeartRadioMMVAs', 864)
# (u'people', 834)
# (u'BTSLoveYourselfTour', 779)
# (u'@YouTube', 720)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:54:30
# -------------------------------------------
# (u'JonelleSleek', 30230)
# (u'Bamfxoxo', 29022)
# (u'nanaziegler', 17877)
# (u'bestmisztake', 16376)
# (u'Amerth205', 12253)
# (u'susi_debra', 7654)
# (u'leemartk', 7178)
# (u'carlosbs18', 6570)
# (u'jooja_8', 6434)
# (u'hakkag1', 5805)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:54:30
# -------------------------------------------
# (u'@BTS_twt', 1896)
# (u'McCain', 1602)
# (u'FFArtistShawn', 1079)
# (u'YTUnfreezeIDOL', 952)
# (u'180825', 948)
# (u'@realDonaldTrump', 864)
# (u'iHeartRadioMMVAs', 864)
# (u'people', 858)
# (u'BTSLoveYourselfTour', 779)
# (u'@YouTube', 728)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:54:40
# -------------------------------------------
# (u'MiLOKMAT', 56378)
# (u'biore_faceca_jp', 53954)
# (u'trs7968trs', 35158)
# (u'Sanddragger', 28246)
# (u'ClllD__', 21711)
# (u'wasn1427', 17089)
# (u'wonderfullone', 16735)
# (u'AnnyTwittou', 13843)
# (u'roumeost', 10763)
# (u'texasps', 10723)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:54:40
# -------------------------------------------
# (u'@BTS_twt', 1928)
# (u'McCain', 1644)
# (u'FFArtistShawn', 1118)
# (u'YTUnfreezeIDOL', 1008)
# (u'180825', 972)
# (u'@realDonaldTrump', 928)
# (u'iHeartRadioMMVAs', 896)
# (u'people', 882)
# (u'BTSLoveYourselfTour', 817)
# (u'@YouTube', 760)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:54:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-08-26 02:54:50
# -------------------------------------------
# (u'@BTS_twt', 1928)
# (u'McCain', 1644)
# (u'FFArtistShawn', 1118)
# (u'YTUnfreezeIDOL', 1008)
# (u'180825', 972)
# (u'@realDonaldTrump', 928)
# (u'iHeartRadioMMVAs', 896)
# (u'people', 882)
# (u'BTSLoveYourselfTour', 817)
# (u'@YouTube', 760)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:55:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-08-26 02:55:00
# -------------------------------------------
# (u'@BTS_twt', 1928)
# (u'McCain', 1644)
# (u'FFArtistShawn', 1118)
# (u'YTUnfreezeIDOL', 1008)
# (u'180825', 972)
# (u'@realDonaldTrump', 928)
# (u'iHeartRadioMMVAs', 896)
# (u'people', 882)
# (u'BTSLoveYourselfTour', 817)
# (u'@YouTube', 760)
# ...
#
# -------------------------------------------
# Time: 2018-08-26 02:55:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-08-26 02:55:10
# -------------------------------------------
# (u'@BTS_twt', 1928)
# (u'McCain', 1644)
# (u'FFArtistShawn', 1118)
# (u'YTUnfreezeIDOL', 1008)
# (u'180825', 972)
# (u'@realDonaldTrump', 928)
# (u'iHeartRadioMMVAs', 896)
# (u'people', 882)
# (u'BTSLoveYourselfTour', 817)
# (u'@YouTube', 760)
# ...
